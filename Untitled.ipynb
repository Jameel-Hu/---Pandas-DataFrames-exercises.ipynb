# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# <ipython-input-1-c2a0fb673da6>:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 2.2.0

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968] ]

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ["name", "sex","first_appearance"]
marvel_df.columns = col_names

# %%
marvel_df
# Out:
#                 name     sex   first_appearance
# 0         Spider-Man    male               1962
# 1    Captain America    male               1941
# 2          Wolverine    male               1974
# 3           Iron Man    male               1963
# 4               Thor    male               1963
# 5              Thing    male               1961
# 6   Mister Fantastic    male               1961
# 7               Hulk    male               1962
# 8              Beast    male               1963
# 9    Invisible Woman  female               1961
# 10             Storm  female               1975
# 11             Namor    male               1939
# 12           Hawkeye    male               1964
# 13         Daredevil    male               1964
# 14    Doctor Strange    male               1963
# 15          Hank Pym    male               1962
# 16     Scarlet Witch  female               1964
# 17              Wasp  female               1963
# 18       Black Widow  female               1964
# 19            Vision    male               1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex   first_appearance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Namor               male               1939
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Hank Pym            male               1962
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex   first_appearance
# name
# Spider-Man          male               1962
# Captain America     male               1941
# Wolverine           male               1974
# Iron Man            male               1963
# Thor                male               1963
# Thing               male               1961
# Mister Fantastic    male               1961
# Hulk                male               1962
# Beast               male               1963
# Invisible Woman   female               1961
# Storm             female               1975
# Hawkeye             male               1964
# Daredevil           male               1964
# Doctor Strange      male               1963
# Scarlet Witch     female               1964
# Wasp              female               1963
# Black Widow       female               1964
# Vision              male               1968

# %%
marvel_df.iloc[:5,]
# Out:
#                   sex   first_appearance
# name
# Spider-Man       male               1962
# Captain America  male               1941
# Wolverine        male               1974
# Iron Man         male               1963
# Thor             male               1963

# %%
marvel_df.iloc[-5:,]
# Out:
#              name     sex  first_appearance
# 15       Hank Pym    male              1962
# 16  Scarlet Witch  female              1964
# 17           Wasp  female              1963
# 18    Black Widow  female              1964
# 19         Vision    male              1968

# %%
marvel_df.iloc[:5,].sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.loc ['vision', 'first_appearance'] = 1964
marvel_df.loc['Vision', 'first_appearance'] = 1964

# %%
marvel_df['years_since'] = 2024 - marvel_df['first_appearance']
marvel_df
# Out:
#                               name     sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man    male            1962.0         62.0
# Captain America    Captain America    male            1941.0         83.0
# Wolverine                Wolverine    male            1974.0         50.0
# Iron Man                  Iron Man    male            1963.0         61.0
# Thor                          Thor    male            1963.0         61.0
# Thing                        Thing    male            1961.0         63.0
# Mister Fantastic  Mister Fantastic    male            1961.0         63.0
# Hulk                          Hulk    male            1962.0         62.0
# Beast                        Beast    male            1963.0         61.0
# Invisible Woman    Invisible Woman  female            1961.0         63.0
# Storm                        Storm  female            1975.0         49.0
# Namor                        Namor    male            1939.0         85.0
# Hawkeye                    Hawkeye    male            1964.0         60.0
# Daredevil                Daredevil    male            1964.0         60.0
# Doctor Strange      Doctor Strange    male            1963.0         61.0
# Hank Pym                  Hank Pym    male            1962.0         62.0
# Scarlet Witch        Scarlet Witch  female            1964.0         60.0
# Wasp                          Wasp  female            1963.0         61.0
# Black Widow            Black Widow  female            1964.0         60.0
# Vision                      Vision    male            1964.0         60.0
# vision                         NaN     NaN            1964.0         60.0

# %%
mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'male'
mask
# Out:
# name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Hank Pym             True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
#                 name     sex  first_appearance  years_since
# name
# Wolverine  Wolverine    male            1974.0         50.0
# Storm          Storm  female            1975.0         49.0

# %%
marvel_df.index = marvel_df['name']

# %%
marvel_df
# Out:
#                               name     sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man    male            1962.0         62.0
# Captain America    Captain America    male            1941.0         83.0
# Wolverine                Wolverine    male            1974.0         50.0
# Iron Man                  Iron Man    male            1963.0         61.0
# Thor                          Thor    male            1963.0         61.0
# Thing                        Thing    male            1961.0         63.0
# Mister Fantastic  Mister Fantastic    male            1961.0         63.0
# Hulk                          Hulk    male            1962.0         62.0
# Beast                        Beast    male            1963.0         61.0
# Invisible Woman    Invisible Woman  female            1961.0         63.0
# Storm                        Storm  female            1975.0         49.0
# Namor                        Namor    male            1939.0         85.0
# Hawkeye                    Hawkeye    male            1964.0         60.0
# Daredevil                Daredevil    male            1964.0         60.0
# Doctor Strange      Doctor Strange    male            1963.0         61.0
# Hank Pym                  Hank Pym    male            1962.0         62.0
# Scarlet Witch        Scarlet Witch  female            1964.0         60.0
# Wasp                          Wasp  female            1963.0         61.0
# Black Widow            Black Widow  female            1964.0         60.0
# Vision                      Vision    male            1964.0         60.0
# NaN                            NaN     NaN            1964.0         60.0

# %%
marvel_df
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male            1962.0         62.0
# Captain America     male            1941.0         83.0
# Wolverine           male            1974.0         50.0
# Iron Man            male            1963.0         61.0
# Thor                male            1963.0         61.0
# Thing               male            1961.0         63.0
# Mister Fantastic    male            1961.0         63.0
# Hulk                male            1962.0         62.0
# Beast               male            1963.0         61.0
# Invisible Woman   female            1961.0         63.0
# Storm             female            1975.0         49.0
# Namor               male            1939.0         85.0
# Hawkeye             male            1964.0         60.0
# Daredevil           male            1964.0         60.0
# Doctor Strange      male            1963.0         61.0
# Hank Pym            male            1962.0         62.0
# Scarlet Witch     female            1964.0         60.0
# Wasp              female            1963.0         61.0
# Black Widow       female            1964.0         60.0
# Vision              male            1964.0         60.0
# NaN                  NaN            1964.0         60.0

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]
# Out:
#           sex  first_appearance  years_since
# name
# Storm  female            1975.0         49.0

# %%
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         21.000000    21.000000
# mean        1961.761905    62.238095
# std            8.104966     8.104966
# min         1939.000000    49.000000
# 25%         1962.000000    60.000000
# 50%         1963.000000    61.000000
# 75%         1964.000000    62.000000
# max         1975.000000    85.000000

# %%
marvel_df.first_appearance.mean()
# Out:
# 1961.7619047619048

# %%
marvel_df.first_appearance.min()
# Out:
# 1939.0

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#         sex  first_appearance  years_since
# name
# Namor  male            1939.0         85.0

# %%
marvel_df.first_appearance.plot()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 17.,  0.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)
